# %% [markdown]
# ## phase 1. Data Collection

# %% [markdown]
# ### 1. Import Libraries

# %%
import pandas as pd
import requests
import time
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### 2. Load Wallet Addresses

# %%
# Load wallet list
df = pd.read_csv("wallet_id.csv")
df.columns = df.columns.str.strip()

wallets = df["wallet_id"].dropna().tolist()
print("Total wallets loaded:", len(wallets))
# Out:
# Total wallets loaded: 103

# %% [markdown]
# ### 3. Define API Key

# %%
# Covalent API key
api_key = "cqt_rQgXvWBXy6Km7myBRQf8FcgR6pqF"

# %% [markdown]
# ### 4. Define Function to Fetch Transactions

# %%
import requests
import time

def fetch_wallet_transactions(wallet_address, retries=3):
    api_key = "cqt_rQgXvWBXy6Km7myBRQf8FcgR6pqF"  
    url = f"https://api.covalenthq.com/v1/1/address/{wallet_address}/transactions_v2/?key={api_key}"
    
    for attempt in range(retries):
        print(f"Attempt {attempt+1} for {wallet_address}") 
        
        try:
            response = requests.get(url)
            print(f"Status Code: {response.status_code}")  
            
            if response.status_code == 200:
                data = response.json()
                txs = data.get("data", {}).get("items", [])
                
                print(f"Transactions fetched: {len(txs)}")
                return txs
            else:
                print(f"Error {response.status_code} for wallet {wallet_address}")
                return []
        
        except Exception as e:
            print(f"Exception on attempt {attempt+1}: {e}")
            time.sleep(1)
    
    print("❗ All attempts failed.")
    return []

# %%
test_wallet = "0x0039f22efb07a647557c7c5d17854cfd6d489ef3"
transactions = fetch_wallet_transactions(test_wallet)
print(f"Total transactions returned: {len(transactions)}")
# Out:
# Attempt 1 for 0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# Status Code: 200
# Transactions fetched: 100
# Total transactions returned: 100

# %% [markdown]
# ### 5. Loop Over Wallets to Collect Transactions

# %%
all_transactions = []

for i, wallet in enumerate(wallets):
    print(f"Processing wallet {i+1}/{len(wallets)}: {wallet}")
    txs = fetch_wallet_transactions(wallet)
    
    for tx in txs:
        all_transactions.append({
            "wallet_address": wallet,
            "tx_hash": tx.get("tx_hash"),
            "block_signed_at": tx.get("block_signed_at"),
            "value": tx.get("value"),
            "from_address": tx.get("from_address"),
            "to_address": tx.get("to_address"),
            "gas_spent": tx.get("gas_spent"),
            "successful": tx.get("successful"),
        })
    
    time.sleep(1)  # respect API rate limit
# Out:
# Processing wallet 1/103: 0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# Attempt 1 for 0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 2/103: 0x06b51c6882b27cb05e712185531c1f74996dd988
# Attempt 1 for 0x06b51c6882b27cb05e712185531c1f74996dd988
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 3/103: 0x0795732aacc448030ef374374eaae57d2965c16c
# Attempt 1 for 0x0795732aacc448030ef374374eaae57d2965c16c
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 4/103: 0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9
# Attempt 1 for 0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9
# Status Code: 200
# Transactions fetched: 80
# Processing wallet 5/103: 0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae
# Attempt 1 for 0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 6/103: 0x104ae61d8d487ad689969a17807ddc338b445416
# Attempt 1 for 0x104ae61d8d487ad689969a17807ddc338b445416
# Status Code: 200
# Transactions fetched: 6
# Processing wallet 7/103: 0x111c7208a7e2af345d36b6d4aace8740d61a3078
# Attempt 1 for 0x111c7208a7e2af345d36b6d4aace8740d61a3078
# Status Code: 200
# Transactions fetched: 6
# Processing wallet 8/103: 0x124853fecb522c57d9bd5c21231058696ca6d596
# Attempt 1 for 0x124853fecb522c57d9bd5c21231058696ca6d596
# Status Code: 200
# Transactions fetched: 7
# Processing wallet 9/103: 0x13b1c8b0e696aff8b4fee742119b549b605f3cbc
# Attempt 1 for 0x13b1c8b0e696aff8b4fee742119b549b605f3cbc
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 10/103: 0x1656f1886c5ab634ac19568cd571bc72f385fdf7
# Attempt 1 for 0x1656f1886c5ab634ac19568cd571bc72f385fdf7
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 11/103: 0x1724e16cb8d0e2aa4d08035bc6b5c56b680a3b22
# Attempt 1 for 0x1724e16cb8d0e2aa4d08035bc6b5c56b680a3b22
# Status Code: 200
# Transactions fetched: 6
# Processing wallet 12/103: 0x19df3e87f73c4aaf4809295561465b993e102668
# Attempt 1 for 0x19df3e87f73c4aaf4809295561465b993e102668
# Status Code: 200
# Transactions fetched: 31
# Processing wallet 13/103: 0x1ab2ccad4fc97c9968ea87d4435326715be32872
# Attempt 1 for 0x1ab2ccad4fc97c9968ea87d4435326715be32872
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 14/103: 0x1c1b30ca93ef57452d53885d97a74f61daf2bf4f
# Attempt 1 for 0x1c1b30ca93ef57452d53885d97a74f61daf2bf4f
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 15/103: 0x1e43dacdcf863676a6bec8f7d6896d6252fac669
# Attempt 1 for 0x1e43dacdcf863676a6bec8f7d6896d6252fac669
# Status Code: 200
# Transactions fetched: 3
# Processing wallet 16/103: 0x22d7510588d90ed5a87e0f838391aaafa707c34b
# Attempt 1 for 0x22d7510588d90ed5a87e0f838391aaafa707c34b
# Status Code: 200
# Transactions fetched: 76
# Processing wallet 17/103: 0x24b3460622d835c56d9a4fe352966b9bdc6c20af
# Attempt 1 for 0x24b3460622d835c56d9a4fe352966b9bdc6c20af
# Status Code: 200
# Transactions fetched: 22
# Processing wallet 18/103: 0x26750f1f4277221bdb5f6991473c6ece8c821f9d
# Attempt 1 for 0x26750f1f4277221bdb5f6991473c6ece8c821f9d
# Status Code: 200
# Transactions fetched: 7
# Processing wallet 19/103: 0x27f72a000d8e9f324583f3a3491ea66998275b28
# Attempt 1 for 0x27f72a000d8e9f324583f3a3491ea66998275b28
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 20/103: 0x2844658bf341db96aa247259824f42025e3bcec2
# Attempt 1 for 0x2844658bf341db96aa247259824f42025e3bcec2
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 21/103: 0x2a2fde3e1beb508fcf7c137a1d5965f13a17825e
# Attempt 1 for 0x2a2fde3e1beb508fcf7c137a1d5965f13a17825e
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 22/103: 0x330513970efd9e8dd606275fb4c50378989b3204
# Attempt 1 for 0x330513970efd9e8dd606275fb4c50378989b3204
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 23/103: 0x3361bea43c2f5f963f81ac70f64e6fba1f1d2a97
# Attempt 1 for 0x3361bea43c2f5f963f81ac70f64e6fba1f1d2a97
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 24/103: 0x3867d222ba91236ad4d12c31056626f9e798629c
# Attempt 1 for 0x3867d222ba91236ad4d12c31056626f9e798629c
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 25/103: 0x3a44be4581137019f83021eeee72b7dc57756069
# Attempt 1 for 0x3a44be4581137019f83021eeee72b7dc57756069
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 26/103: 0x3e69ad05716bdc834db72c4d6d44439a7c8a902b
# Attempt 1 for 0x3e69ad05716bdc834db72c4d6d44439a7c8a902b
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 27/103: 0x427f2ac5fdf4245e027d767e7c3ac272a1f40a65
# Attempt 1 for 0x427f2ac5fdf4245e027d767e7c3ac272a1f40a65
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 28/103: 0x4814be124d7fe3b240eb46061f7ddfab468fe122
# Attempt 1 for 0x4814be124d7fe3b240eb46061f7ddfab468fe122
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 29/103: 0x4839e666e2baf12a51bf004392b35972eeddeabf
# Attempt 1 for 0x4839e666e2baf12a51bf004392b35972eeddeabf
# Status Code: 200
# Transactions fetched: 20
# Processing wallet 30/103: 0x4c4d05fe859279c91b074429b5fc451182cec745
# Attempt 1 for 0x4c4d05fe859279c91b074429b5fc451182cec745
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 31/103: 0x4d997c89bc659a3e8452038a8101161e7e7e53a7
# Attempt 1 for 0x4d997c89bc659a3e8452038a8101161e7e7e53a7
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 32/103: 0x4db0a72edb5ea6c55df929f76e7d5bb14e389860
# Attempt 1 for 0x4db0a72edb5ea6c55df929f76e7d5bb14e389860
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 33/103: 0x4e61251336c32e4fe6bfd5fab014846599321389
# Attempt 1 for 0x4e61251336c32e4fe6bfd5fab014846599321389
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 34/103: 0x4e6e724f4163b24ffc7ffe662b5f6815b18b4210
# Attempt 1 for 0x4e6e724f4163b24ffc7ffe662b5f6815b18b4210
# Status Code: 200
# Transactions fetched: 6
# Processing wallet 35/103: 0x507b6c0d950702f066a9a1bd5e85206f87b065ba
# Attempt 1 for 0x507b6c0d950702f066a9a1bd5e85206f87b065ba
# Status Code: 200
# Transactions fetched: 43
# Processing wallet 36/103: 0x54e19653be9d4143b08994906be0e27555e8834d
# Attempt 1 for 0x54e19653be9d4143b08994906be0e27555e8834d
# Status Code: 200
# Transactions fetched: 7
# Processing wallet 37/103: 0x56ba823641bfc317afc8459bf27feed6eb9ff59f
# Attempt 1 for 0x56ba823641bfc317afc8459bf27feed6eb9ff59f
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 38/103: 0x56cc2bffcb3f86a30c492f9d1a671a1f744d1d2f
# Attempt 1 for 0x56cc2bffcb3f86a30c492f9d1a671a1f744d1d2f
# Status Code: 200
# Transactions fetched: 8
# Processing wallet 39/103: 0x578cea5f899b0dfbf05c7fbcfda1a644b2a47787
# Attempt 1 for 0x578cea5f899b0dfbf05c7fbcfda1a644b2a47787
# Status Code: 200
# Transactions fetched: 11
# Processing wallet 40/103: 0x58c2a9099a03750e9842d3e9a7780cdd6aa70b86
# Attempt 1 for 0x58c2a9099a03750e9842d3e9a7780cdd6aa70b86
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 41/103: 0x58d68d4bcf9725e40353379cec92b90332561683
# Attempt 1 for 0x58d68d4bcf9725e40353379cec92b90332561683
# Status Code: 200
# Transactions fetched: 55
# Processing wallet 42/103: 0x5e324b4a564512ea7c93088dba2f8c1bf046a3eb
# Attempt 1 for 0x5e324b4a564512ea7c93088dba2f8c1bf046a3eb
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 43/103: 0x612a3500559be7be7703de6dc397afb541a16f7f
# Attempt 1 for 0x612a3500559be7be7703de6dc397afb541a16f7f
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 44/103: 0x623af911f493747c216ad389c7805a37019c662d
# Attempt 1 for 0x623af911f493747c216ad389c7805a37019c662d
# Status Code: 200
# Transactions fetched: 70
# Processing wallet 45/103: 0x6a2752a534faacaaa153bffbb973dd84e0e5497b
# Attempt 1 for 0x6a2752a534faacaaa153bffbb973dd84e0e5497b
# Status Code: 200
# Transactions fetched: 15
# Processing wallet 46/103: 0x6d69ca3711e504658977367e13c300ab198379f1
# Attempt 1 for 0x6d69ca3711e504658977367e13c300ab198379f1
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 47/103: 0x6e355417f7f56e7927d1cd971f0b5a1e6d538487
# Attempt 1 for 0x6e355417f7f56e7927d1cd971f0b5a1e6d538487
# Status Code: 200
# Transactions fetched: 16
# Processing wallet 48/103: 0x70c1864282599a762c674dd9d567b37e13bce755
# Attempt 1 for 0x70c1864282599a762c674dd9d567b37e13bce755
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 49/103: 0x70d8e4ab175dfe0eab4e9a7f33e0a2d19f44001e
# Attempt 1 for 0x70d8e4ab175dfe0eab4e9a7f33e0a2d19f44001e
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 50/103: 0x7399dbeebe2f88bc6ac4e3fd7ddb836a4bce322f
# Attempt 1 for 0x7399dbeebe2f88bc6ac4e3fd7ddb836a4bce322f
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 51/103: 0x767055590c73b7d2aaa6219da13807c493f91a20
# Attempt 1 for 0x767055590c73b7d2aaa6219da13807c493f91a20
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 52/103: 0x7851bdfb64bbecfb40c030d722a1f147dff5db6a
# Attempt 1 for 0x7851bdfb64bbecfb40c030d722a1f147dff5db6a
# Status Code: 200
# Transactions fetched: 9
# Processing wallet 53/103: 0x7b4636320daa0bc055368a4f9b9d01bd8ac51877
# Attempt 1 for 0x7b4636320daa0bc055368a4f9b9d01bd8ac51877
# Status Code: 200
# Transactions fetched: 11
# Processing wallet 54/103: 0x7b57dbe2f2e4912a29754ff3e412ed9507fd8957
# Attempt 1 for 0x7b57dbe2f2e4912a29754ff3e412ed9507fd8957
# Status Code: 200
# Transactions fetched: 7
# Processing wallet 55/103: 0x7be3dfb5b6fcbae542ea85e76cc19916a20f6c1e
# Attempt 1 for 0x7be3dfb5b6fcbae542ea85e76cc19916a20f6c1e
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 56/103: 0x7de76a449cf60ea3e111ff18b28e516d89532152
# Attempt 1 for 0x7de76a449cf60ea3e111ff18b28e516d89532152
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 57/103: 0x7e3eab408b9c76a13305ef34606f17c16f7b33cc
# Attempt 1 for 0x7e3eab408b9c76a13305ef34606f17c16f7b33cc
# Status Code: 200
# Transactions fetched: 15
# Processing wallet 58/103: 0x7f5e6a28afc9fb0aaf4259d4ff69991b88ebea47
# Attempt 1 for 0x7f5e6a28afc9fb0aaf4259d4ff69991b88ebea47
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 59/103: 0x83ea74c67d393c6894c34c464657bda2183a2f1a
# Attempt 1 for 0x83ea74c67d393c6894c34c464657bda2183a2f1a
# Status Code: 200
# Transactions fetched: 7
# Processing wallet 60/103: 0x8441fecef5cc6f697be2c4fc4a36feacede8df67
# Attempt 1 for 0x8441fecef5cc6f697be2c4fc4a36feacede8df67
# Status Code: 200
# Transactions fetched: 24
# Processing wallet 61/103: 0x854a873b8f9bfac36a5eb9c648e285a095a7478d
# Attempt 1 for 0x854a873b8f9bfac36a5eb9c648e285a095a7478d
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 62/103: 0x8587d9f794f06d976c2ec1cfd523983b856f5ca9
# Attempt 1 for 0x8587d9f794f06d976c2ec1cfd523983b856f5ca9
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 63/103: 0x880a0af12da55df1197f41697c1a1b61670ed410
# Attempt 1 for 0x880a0af12da55df1197f41697c1a1b61670ed410
# Status Code: 200
# Transactions fetched: 17
# Processing wallet 64/103: 0x8aaece100580b749a20f8ce30338c4e0770b65ed
# Attempt 1 for 0x8aaece100580b749a20f8ce30338c4e0770b65ed
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 65/103: 0x8be38ea2b22b706aef313c2de81f7d179024dd30
# Attempt 1 for 0x8be38ea2b22b706aef313c2de81f7d179024dd30
# Status Code: 200
# Transactions fetched: 33
# Processing wallet 66/103: 0x8d900f213db5205c529aaba5d10e71a0ed2646db
# Attempt 1 for 0x8d900f213db5205c529aaba5d10e71a0ed2646db
# Status Code: 200
# Transactions fetched: 15
# Processing wallet 67/103: 0x91919344c1dad09772d19ad8ad4f1bcd29c51f27
# Attempt 1 for 0x91919344c1dad09772d19ad8ad4f1bcd29c51f27
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 68/103: 0x93f0891bf71d8abed78e0de0885bd26355bb8b1d
# Attempt 1 for 0x93f0891bf71d8abed78e0de0885bd26355bb8b1d
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 69/103: 0x96479b087cb8f236a5e2dcbfc50ce63b2f421da6
# Attempt 1 for 0x96479b087cb8f236a5e2dcbfc50ce63b2f421da6
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 70/103: 0x96bb4447a02b95f1d1e85374cffd565eb22ed2f8
# Attempt 1 for 0x96bb4447a02b95f1d1e85374cffd565eb22ed2f8
# Status Code: 200
# Transactions fetched: 3
# Processing wallet 71/103: 0x9a363adc5d382c04d36b09158286328f75672098
# Attempt 1 for 0x9a363adc5d382c04d36b09158286328f75672098
# Status Code: 200
# Transactions fetched: 12
# Processing wallet 72/103: 0x9ad1331c5b6c5a641acffb32719c66a80c6e1a17
# Attempt 1 for 0x9ad1331c5b6c5a641acffb32719c66a80c6e1a17
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 73/103: 0x9ba0d85f71e145ccf15225e59631e5a883d5d74a
# Attempt 1 for 0x9ba0d85f71e145ccf15225e59631e5a883d5d74a
# Status Code: 200
# Transactions fetched: 60
# Processing wallet 74/103: 0x9e6ec4e98793970a1307262ba68d37594e58cd78
# Attempt 1 for 0x9e6ec4e98793970a1307262ba68d37594e58cd78
# Status Code: 200
# Transactions fetched: 47
# Processing wallet 75/103: 0xa7e94d933eb0c439dda357f61244a485246e97b8
# Attempt 1 for 0xa7e94d933eb0c439dda357f61244a485246e97b8
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 76/103: 0xa7f3c74f0255796fd5d3ddcf88db769f7a6bf46a
# Attempt 1 for 0xa7f3c74f0255796fd5d3ddcf88db769f7a6bf46a
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 77/103: 0xa98dc64bb42575efec7d1e4560c029231ce5da51
# Attempt 1 for 0xa98dc64bb42575efec7d1e4560c029231ce5da51
# Status Code: 200
# Transactions fetched: 11
# Processing wallet 78/103: 0xb271ff7090b39028eb6e711c3f89a3453d5861ee
# Attempt 1 for 0xb271ff7090b39028eb6e711c3f89a3453d5861ee
# Status Code: 200
# Transactions fetched: 8
# Processing wallet 79/103: 0xb475576594ae44e1f75f534f993cbb7673e4c8b6
# Attempt 1 for 0xb475576594ae44e1f75f534f993cbb7673e4c8b6
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 80/103: 0xb57297c5d02def954794e593db93d0a302e43e5c
# Attempt 1 for 0xb57297c5d02def954794e593db93d0a302e43e5c
# Status Code: 200
# Transactions fetched: 11
# Processing wallet 81/103: 0xbd4a00764217c13a246f86db58d74541a0c3972a
# Attempt 1 for 0xbd4a00764217c13a246f86db58d74541a0c3972a
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 82/103: 0xc179d55f7e00e789915760f7d260a1bf6285278b
# Attempt 1 for 0xc179d55f7e00e789915760f7d260a1bf6285278b
# Status Code: 200
# Transactions fetched: 12
# Processing wallet 83/103: 0xc22b8e78394ce52e0034609a67ae3c959daa84bc
# Attempt 1 for 0xc22b8e78394ce52e0034609a67ae3c959daa84bc
# Status Code: 200
# Transactions fetched: 95
# Processing wallet 84/103: 0xcbbd9fe837a14258286bbf2e182cbc4e4518c5a3
# Attempt 1 for 0xcbbd9fe837a14258286bbf2e182cbc4e4518c5a3
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 85/103: 0xcecf5163bb057c1aff4963d9b9a7d2f0bf591710
# Attempt 1 for 0xcecf5163bb057c1aff4963d9b9a7d2f0bf591710
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 86/103: 0xcf0033bf27804640e5339e06443e208db5870dd2
# Attempt 1 for 0xcf0033bf27804640e5339e06443e208db5870dd2
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 87/103: 0xd0df53e296c1e3115fccc3d7cdf4ba495e593b56
# Attempt 1 for 0xd0df53e296c1e3115fccc3d7cdf4ba495e593b56
# Status Code: 200
# Transactions fetched: 6
# Processing wallet 88/103: 0xd1a3888fd8f490367c6104e10b4154427c02dd9c
# Attempt 1 for 0xd1a3888fd8f490367c6104e10b4154427c02dd9c
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 89/103: 0xd334d18fa6bada9a10f361bae42a019ce88a3c33
# Attempt 1 for 0xd334d18fa6bada9a10f361bae42a019ce88a3c33
# Status Code: 200
# Transactions fetched: 6
# Processing wallet 90/103: 0xd9d3930ffa343f5a0eec7606d045d0843d3a02b4
# Attempt 1 for 0xd9d3930ffa343f5a0eec7606d045d0843d3a02b4
# Status Code: 200
# Transactions fetched: 8
# Processing wallet 91/103: 0xdde73df7bd4d704a89ad8421402701b3a460c6e9
# Attempt 1 for 0xdde73df7bd4d704a89ad8421402701b3a460c6e9
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 92/103: 0xde92d70253604fd8c5998c8ee3ed282a41b33b7f
# Attempt 1 for 0xde92d70253604fd8c5998c8ee3ed282a41b33b7f
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 93/103: 0xded1f838ae6aa5fcd0f13481b37ee88e5bdccb3d
# Attempt 1 for 0xded1f838ae6aa5fcd0f13481b37ee88e5bdccb3d
# Status Code: 200
# Transactions fetched: 12
# Processing wallet 94/103: 0xebb8629e8a3ec86cf90cb7600264415640834483
# Attempt 1 for 0xebb8629e8a3ec86cf90cb7600264415640834483
# Status Code: 200
# Transactions fetched: 8
# Processing wallet 95/103: 0xeded1c8c0a0c532195b8432153f3bfa81dba2a90
# Attempt 1 for 0xeded1c8c0a0c532195b8432153f3bfa81dba2a90
# Status Code: 200
# Transactions fetched: 5
# Processing wallet 96/103: 0xf10fd8921019615a856c1e95c7cd3632de34edc4
# Attempt 1 for 0xf10fd8921019615a856c1e95c7cd3632de34edc4
# Status Code: 200
# Transactions fetched: 76
# Processing wallet 97/103: 0xf340b9f2098f80b86fbc5ede586c319473aa11f3
# Attempt 1 for 0xf340b9f2098f80b86fbc5ede586c319473aa11f3
# Status Code: 200
# Transactions fetched: 100
# Processing wallet 98/103: 0xf54f36bca969800fd7d63a68029561309938c09b
# Attempt 1 for 0xf54f36bca969800fd7d63a68029561309938c09b
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 99/103: 0xf60304b534f74977e159b2e159e135475c245526
# Attempt 1 for 0xf60304b534f74977e159b2e159e135475c245526
# Status Code: 200
# Transactions fetched: 18
# Processing wallet 100/103: 0xf67e8e5805835465f7eba988259db882ab726800
# Attempt 1 for 0xf67e8e5805835465f7eba988259db882ab726800
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 101/103: 0xf7aa5d0752cfcd41b0a5945867d619a80c405e52
# Attempt 1 for 0xf7aa5d0752cfcd41b0a5945867d619a80c405e52
# Status Code: 200
# Transactions fetched: 4
# Processing wallet 102/103: 0xf80a8b9cfff0febf49914c269fb8aead4a22f847
# Attempt 1 for 0xf80a8b9cfff0febf49914c269fb8aead4a22f847
# Status Code: 200
# Transactions fetched: 13
# Processing wallet 103/103: 0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# Attempt 1 for 0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# Status Code: 200
# Transactions fetched: 4

# %% [markdown]
# ### 6. Save Raw Transactions to CSV

# %%
tx_df = pd.DataFrame(all_transactions)
tx_df.to_csv("wallet_transactions.csv", index=False)
print("Saved wallet_transactions.csv with", len(tx_df), "rows")
# Out:
# Saved wallet_transactions.csv with 2823 rows

# %% [markdown]
# ### 7.Load CSV

# %%
df=pd.read_csv("wallet_transactions.csv")

# %%
df
# Out:
#                                   wallet_address  \
# 0     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 1     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 2     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 3     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# 4     0x0039f22efb07a647557c7c5d17854cfd6d489ef3
# ...                                          ...
# 2818  0xf80a8b9cfff0febf49914c269fb8aead4a22f847
# 2819  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# 2820  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# 2821  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# 2822  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
#
#                                                 tx_hash       block_signed_at  \
# 0     0x98703fb4a7c6804d82e98f009ecc0e089abd53de9469...  2025-06-16T21:15:11Z
# 1     0x0b8e89905717b9babd69aa7db6af0afb83331e9b8041...  2025-04-27T21:09:35Z
# 2     0x5745f6d2e9397ed8ceb7120f42761e1f04643e132e94...  2025-03-24T23:27:47Z
# 3     0x35cd404392ac9b7786bee78e4bfb2773cbb576b9c3dc...  2025-02-23T19:08:59Z
# 4     0x51a4f04abaa498409b72d83b4365440f0738ac5bcca1...  2025-02-11T03:05:11Z
# ...                                                 ...                   ...
# 2818  0x55030001bba1945f08497ff31ea3e836ba48b68b4726...  2020-07-29T06:16:50Z
# 2819  0xe76b49f4a25d49d8e5279e905ca683488f1a21313e57...  2020-10-21T18:51:46Z
# 2820  0x5a10a092184342b7e2132f7a60868a735c78b85445ed...  2020-10-21T18:51:31Z
# 2821  0xf2135f7e2a3490c5706f36def69926a5b3ae71140bab...  2020-10-21T11:57:13Z
# 2822  0x9c2708de3fa45580cb33d08d144b3888b4f360f416f0...  2020-10-21T11:56:05Z
#
#                   value                                from_address  \
# 0                     0  0xc6b602de080fc9ac9d96a431b2d749d38e77cbbc
# 1                     0  0xfd0ce77ca6521e3cbbcfb07398cca8ec2648115d
# 2                     0  0xc07aff7c831105bacaf2fb4d9506332112eee2a1
# 3                     0  0xad38352c725c6768c11a9a71bc7d921a9355d56c
# 4                     0  0x1e6971036be043c0e2457fe3f6dbed9f73354c6b
# ...                 ...                                         ...
# 2818                  0  0xfdcab1b4e6292ddd540a3c535f36d32d879aa78a
# 2819                  0  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# 2820                  0  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac
# 2821                  0  0x73008d40648d3ccd191d9af6889159c15089095d
# 2822  18600000000000000  0x9c88429c3f1e701cfe5fe4c8536f90440fac6c47
#
#                                       to_address  gas_spent  successful
# 0     0x13173761e24c3708495b1dd314920f67f97011d0      55815        True
# 1                                            NaN    5264347        True
# 2                                            NaN    5226097        True
# 3                                            NaN    5213387        True
# 4                                            NaN    5244910        True
# ...                                          ...        ...         ...
# 2818  0x1c647c67c1aad0ebff25500f3b3084d3d2872eba     535112        True
# 2819  0x39aa39c021dfbae8fac545936693ac917d5e7563     202784        True
# 2820  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48      49811        True
# 2821  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48      42369        True
# 2822  0xfe5a05c0f8b24fca15a7306f6a4ebb7dcf2186ac      21000        True
#
# [2823 rows x 8 columns]

# %% [markdown]
# ## phase 2.Feature Engineering

# %%
import pandas as pd

# Load your collected transaction data
df = pd.read_csv("wallet_transactions.csv")

# Clean column names if needed
df.columns = df.columns.str.strip()

# Convert timestamp to datetime
df['block_signed_at'] = pd.to_datetime(df['block_signed_at'])

# Calculate USD value per transaction (optional, here just using 'value')
df['value'] = pd.to_numeric(df['value'], errors='coerce').fillna(0)

# Aggregate features per wallet
features = df.groupby('wallet_address').agg(
    total_transactions=('tx_hash', 'count'),
    total_value=('value', 'sum'),
    avg_value=('value', 'mean'),
    gas_spent=('gas_spent', 'sum'),
    unique_to_addresses=('to_address', pd.Series.nunique),
    unique_from_addresses=('from_address', pd.Series.nunique),
    first_tx=('block_signed_at', 'min'),
    last_tx=('block_signed_at', 'max'),
    success_rate=('successful', lambda x: x.sum() / len(x))
).reset_index()

features['activity_days'] = (features['last_tx'] - features['first_tx']).dt.days + 1

# Save to CSV for next step
features.to_csv("wallet_features.csv", index=False)
print("Step 2 done: wallet_features.csv generated.")
# Out:
# Step 2 done: wallet_features.csv generated.

# %% [markdown]
# ## phase 3: Assigning Wallet Risk Scores (0–1000)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

features = pd.read_csv("wallet_features.csv")

score_columns = ['total_transactions', 'total_value', 'avg_value', 'gas_spent', 'success_rate', 'activity_days']

features[score_columns] = features[score_columns].fillna(0)

# Normalize the selected features to range [0, 1]
scaler = MinMaxScaler()
normalized = scaler.fit_transform(features[score_columns])
features_normalized = pd.DataFrame(normalized, columns=score_columns)

features['score'] = (features_normalized.mean(axis=1) * 1000).astype(int)

final_scores = features[['wallet_address', 'score']]
final_scores.columns = ['wallet_id', 'score']

final_scores.to_csv("wallet_scores.csv", index=False)
print(" Step 3 done: wallet_scores.csv generated.")
# Out:
#  Step 3 done: wallet_scores.csv generated.

# %%
df = pd.read_csv("wallet_scores.csv")
print(df.head())
# Out:
#                                     wallet_id  score
# 0  0x0039f22efb07a647557c7c5d17854cfd6d489ef3    505
# 1  0x06b51c6882b27cb05e712185531c1f74996dd988    170
# 2  0x0795732aacc448030ef374374eaae57d2965c16c    168
# 3  0x0aaa79f1a86bc8136cd0d1ca0d51964f4e3766f9    542
# 4  0x0fe383e5abc200055a7f391f94a5f5d1f844b9ae    173
